# %%
# %matplotlib inline

# %%
import glob
files = glob.glob("*.dcm")

# %%
def getResponse():
  try:
    r = raw_input("[S]elect,[N]ext, [P]revious")
    if r[0].upper() in ["S","N","P"]:
        return r[0].upper()
    else:
        return getResponse()
  except IndexError:
      return getResponse()

# %%
import dicom
from matplotlib import pyplot as pp
from IPython.html.widgets import interact

# %%
dcm = dicom.read_file(files[0])
pp.imshow(dcm.pixel_array)

# %%
ic = 0
pp.gray()

# %%
def showImage(files):
    print files
    dcm = dicom.read_file(files)
    pp.imshow(dcm.pixel_array)
    pp.show()

# %%
def browse_images(files):
    n = len(files)
    def view_image(i):
        dcm = dicom.read_file(files[i])
        pp.imshow(dcm.pixel_array)#, cmap=pp.cm.gray_r, interpolation='nearest')
        pp.title('Training: %s' % files[i])
        pp.show()
    interact(view_image, i=(0,n-1))

# %%
browse_images(files)

# %%
KeepGoin = True
dcm = dicom.read_file(files[0])
showImage(dcm)
while KeepGoin:
    print ic
    dcm = dicom.read_file(files[ic])
    showImage(dcm)

    resp = getResponse()
    if resp == 'S':
        print f,dcm.InstanceNumber,dcm.SliceLocation
    elif resp == 'N':
        ic  = min(len(files)-1,ic+1)
    else:
        ic = max(0,ic-1)
# Out:
# 3
# [S]elect,[N]ext, [P]reviousn
# 4
# [S]elect,[N]ext, [P]reviousn
# 5
# [S]elect,[N]ext, [P]reviousn
# 6
# [S]elect,[N]ext, [P]reviousn
# 7
# [S]elect,[N]ext, [P]reviousn
# 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-4fe3ee627693> in <module>()
#       7     showImage(dcm)
#       8
# ----> 9     resp = getResponse()
#      10     if resp == 'S':
#      11         print f,dcm.InstanceNumber,dcm.SliceLocation
#
# <ipython-input-3-4fe6890aca88> in getResponse()
#       1 def getResponse():
#       2   try:
# ----> 3     r = raw_input("[S]elect,[N]ext, [P]revious")
#       4     if r[0].upper() in ["S","N","P"]:
#       5         return r[0].upper()
#
# /Users/brian/anaconda/lib/python2.7/site-packages/IPython/kernel/zmq/ipkernel.pyc in <lambda>(prompt)
#     361         # raw_input in the user namespace.
# ...
